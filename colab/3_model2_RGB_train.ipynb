# %% [markdown]
# <a href="https://colab.research.google.com/github/FullFran/AAFD_Gender_Age_classifier/blob/master/colab/3_model2_RGB_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importamos las librerías que vamos a utilizar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input, BatchNormalization
from keras.models import Sequential, Model
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')

# '/content/drive/MyDrive/datos.csv'
# Out:
# Mounted at /content/drive

# %%
# %ls
# Out:
# drive/  model3-RGB.h5  sample_data/

# %%
# Cargamos los datos que vamos a utilizar.
df_train = pd.read_csv('/content/drive/MyDrive/prueba final/train-processed.csv')
df_val = pd.read_csv('/content/drive/MyDrive/prueba final/val-processed.csv')

images_train = np.load(
    '/content/drive/MyDrive/prueba final/image_array100_train.npy', allow_pickle=True)
images_val = np.load(
    '/content/drive/MyDrive/prueba final/image_array100_val.npy', allow_pickle=True)

# %%
print(images_train.shape)
print(images_val.shape)
# Out:
# (6637, 100, 100, 3)
# (6685, 100, 100, 3)

# %%
X = images_train
y_gender = df_train['Gender']
y_age_raw = df_train['Age']
# Normalizamos los datos de edad para obtener mejor convergencia
# 80 es el mayor dato de edad según el autor del set de datos.
y_age = y_age_raw / 80 

y_gender = np.array(y_gender)
y_age = np.array(y_age)

print('Dimensiones de X:', X.shape)
print('Dimensiones de y_gender:', y_gender.shape)
print('Dimensiones de y_age:', y_age.shape)
# Out:
# Dimensiones de X: (6637, 100, 100, 3)
# Dimensiones de y_gender: (6637,)
# Dimensiones de y_age: (6637,)

# %%
X_val = images_val
y_gender_val = df_val['Gender']
y_age_raw_val = df_val['Age']
y_age_val = y_age_raw_val / 80

y_gender_val = np.array(y_gender_val)
y_age_val = np.array(y_age_val)

print('Dimensiones de X:', X_val.shape)
print('Dimensiones de y_gender:', y_gender_val.shape)
print('Dimensiones de y_age:', y_age_val.shape)
# Out:
# Dimensiones de X: (6685, 100, 100, 3)
# Dimensiones de y_gender: (6685,)
# Dimensiones de y_age: (6685,)

# %%
# Verificamos que todo esté correcto:
plt.figure(figsize=(10, 4))

for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X[i])
    plt.xlabel(f'Edad: {int(80*y_age[i])}')
    plt.ylabel(f'Género: {y_gender[i]}')
plt.show()

# %%
# Definición de la entrada
inputs = Input(shape=(100, 100, 3), name='input_1')

# Capas de convolución
conv_1 = Conv2D(64, kernel_size=(3, 3), activation='relu', name='conv2d_1')(inputs)
conv_2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(conv_1)
maxpool_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
batchnorm_2 = BatchNormalization()(maxpool_2)
dropout_2 = Dropout(0.15)(batchnorm_2)

conv_3 = Conv2D(128, kernel_size=(3, 3), activation='relu')(dropout_2)
conv_4 = Conv2D(128, kernel_size=(3, 3), activation='relu')(conv_3)
maxpool_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)
batchnorm_4 = BatchNormalization()(maxpool_4)
dropout_4 = Dropout(0.15)(batchnorm_4)

conv_5 = Conv2D(128, kernel_size=(3, 3), activation='relu')(dropout_4)
conv_6 = Conv2D(128, kernel_size=(3, 3), activation='relu')(conv_5)
maxpool_6 = MaxPooling2D(pool_size=(2, 2))(conv_6)
batchnorm_6 = BatchNormalization()(maxpool_6)
dropout_6 = Dropout(0.15)(batchnorm_6)

conv_7 = Conv2D(256, kernel_size=(3, 3), activation='relu')(dropout_6)
conv_8 = Conv2D(256, kernel_size=(3, 3), activation='relu')(conv_7)
maxpool_8 = MaxPooling2D(pool_size=(2, 2))(conv_8)
batchnorm_8 = BatchNormalization()(maxpool_8)
dropout_8 = Dropout(0.15)(batchnorm_8)

conv_9 = Conv2D(256, kernel_size=(2, 2), activation='relu', padding='same')(dropout_8)
conv_10 = Conv2D(256, kernel_size=(2, 2), activation='relu', padding='same')(conv_9)
maxpool_10 = MaxPooling2D(pool_size=(2, 2))(conv_10)
batchnorm_10 = BatchNormalization()(maxpool_10)
dropout_10 = Dropout(0.15)(batchnorm_10)

# Capa de aplanamiento
flatten = Flatten()(dropout_10)

# Capas totalmente conectadas
dense_1 = Dense(256, activation='relu', name='dense_1')(flatten)
dense_2 = Dense(256, activation='relu', name='dense_2')(flatten)

# Capas de dropout
dropout_1 = Dropout(0.3, name='dropout_1')(dense_1)
dropout_2 = Dropout(0.3, name='dropout_2')(dense_2)

# Capas de salida
output_1 = Dense(1, activation='sigmoid', name='gender_out')(dropout_1)
output_2 = Dense(1, activation='relu', name='age_out')(dropout_2)

# Creación del modelo
model = Model(inputs=inputs, outputs=[output_1, output_2])

# Resumen del modelo
model.summary()

model.compile(loss=['binary_crossentropy', 'mae'],
              optimizer='adam', metrics=['accuracy', 'mae'])
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 98, 98, 64)   1792        ['input_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 96, 96, 64)   36928       ['conv2d_1[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 48, 48, 64)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 48, 48, 64)  256         ['max_pooling2d_5[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 48, 48, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 46, 46, 128)  73856       ['dropout_5[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 44, 44, 128)  147584      ['conv2d_10[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 22, 22, 128)  0          ['conv2d_11[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 22, 22, 128)  512        ['max_pooling2d_6[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 22, 22, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 20, 20, 128)  147584      ['dropout_6[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 18, 18, 128)  147584      ['conv2d_12[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 9, 9, 128)   0           ['conv2d_13[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 9, 9, 128)   512         ['max_pooling2d_7[0][0]']
#  rmalization)
#
#  dropout_7 (Dropout)            (None, 9, 9, 128)    0           ['batch_normalization_7[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 7, 7, 256)    295168      ['dropout_7[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 5, 5, 256)    590080      ['conv2d_14[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 2, 2, 256)   0           ['conv2d_15[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 2, 2, 256)   1024        ['max_pooling2d_8[0][0]']
#  rmalization)
#
#  dropout_8 (Dropout)            (None, 2, 2, 256)    0           ['batch_normalization_8[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 2, 2, 256)    262400      ['dropout_8[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 2, 2, 256)    262400      ['conv2d_16[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 1, 1, 256)   0           ['conv2d_17[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 1, 1, 256)   1024        ['max_pooling2d_9[0][0]']
#  rmalization)
#
#  dropout_9 (Dropout)            (None, 1, 1, 256)    0           ['batch_normalization_9[0][0]']
#
#  flatten_1 (Flatten)            (None, 256)          0           ['dropout_9[0][0]']
#
#  dense_1 (Dense)                (None, 256)          65792       ['flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 256)          65792       ['flatten_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 256)          0           ['dense_2[0][0]']
#
#  gender_out (Dense)             (None, 1)            257         ['dropout_1[0][0]']
#
#  age_out (Dense)                (None, 1)            257         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 2,100,802
# Trainable params: 2,099,138
# Non-trainable params: 1,664
# __________________________________________________________________________________________________

# %%
ckpt_path = 'model1-RGB.h5'
# Crear el callback para guardar los pesos
checkpoint_callback = ModelCheckpoint(
    filepath=ckpt_path,
    save_weights_only=False,
    monitor='val_loss',  # Monitorear la pérdida en el conjunto de validación
    save_best_only=True,  # Guardar solo los pesos del mejor modelo según la métrica monitoreada
    mode='min',  # Modo 'min' para minimizar la pérdida
    verbose=1)  # Imprimir mensajes al guardar los pesos

# EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Entrenamos al modelo:
history = model.fit(x=X, y={'gender_out': y_gender, 'age_out': y_age}, batch_size=32, 
                    epochs=20, validation_data=(X_val, {'gender_out': y_gender_val, 'age_out': y_age_val}),callbacks=[early_stopping, checkpoint_callback] )
# Out:
# Epoch 1/20
# 208/208 [==============================] - ETA: 0s - loss: 1.1046 - gender_out_loss: 0.6695 - age_out_loss: 0.4351 - gender_out_accuracy: 0.6411 - gender_out_mae: 0.4055 - age_out_accuracy: 1.5067e-04 - age_out_mae: 0.4351
# Epoch 1: val_loss improved from inf to 1.44237, saving model to model1-RGB.h5
# 208/208 [==============================] - 41s 106ms/step - loss: 1.1046 - gender_out_loss: 0.6695 - age_out_loss: 0.4351 - gender_out_accuracy: 0.6411 - gender_out_mae: 0.4055 - age_out_accuracy: 1.5067e-04 - age_out_mae: 0.4351 - val_loss: 1.4424 - val_gender_out_loss: 1.0097 - val_age_out_loss: 0.4326 - val_gender_out_accuracy: 0.4459 - val_gender_out_mae: 0.5249 - val_age_out_accuracy: 0.0000e+00 - val_age_out_mae: 0.4326
# Epoch 2/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.9680 - gender_out_loss: 0.5733 - age_out_loss: 0.3948 - gender_out_accuracy: 0.7067 - gender_out_mae: 0.3566 - age_out_accuracy: 6.0386e-04 - age_out_mae: 0.3948
# Epoch 2: val_loss improved from 1.44237 to 0.85038, saving model to model1-RGB.h5
# 208/208 [==============================] - 18s 88ms/step - loss: 0.9676 - gender_out_loss: 0.5731 - age_out_loss: 0.3945 - gender_out_accuracy: 0.7069 - gender_out_mae: 0.3565 - age_out_accuracy: 6.0268e-04 - age_out_mae: 0.3945 - val_loss: 0.8504 - val_gender_out_loss: 0.5355 - val_age_out_loss: 0.3149 - val_gender_out_accuracy: 0.7240 - val_gender_out_mae: 0.3558 - val_age_out_accuracy: 1.4959e-04 - val_age_out_mae: 0.3149
# Epoch 3/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.7385 - gender_out_loss: 0.4676 - age_out_loss: 0.2709 - gender_out_accuracy: 0.7817 - gender_out_mae: 0.2917 - age_out_accuracy: 0.0018 - age_out_mae: 0.2709
# Epoch 3: val_loss improved from 0.85038 to 0.68867, saving model to model1-RGB.h5
# 208/208 [==============================] - 18s 88ms/step - loss: 0.7381 - gender_out_loss: 0.4671 - age_out_loss: 0.2710 - gender_out_accuracy: 0.7820 - gender_out_mae: 0.2913 - age_out_accuracy: 0.0018 - age_out_mae: 0.2710 - val_loss: 0.6887 - val_gender_out_loss: 0.5139 - val_age_out_loss: 0.1748 - val_gender_out_accuracy: 0.7536 - val_gender_out_mae: 0.3024 - val_age_out_accuracy: 0.0010 - val_age_out_mae: 0.1748
# Epoch 4/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.6370 - gender_out_loss: 0.4140 - age_out_loss: 0.2230 - gender_out_accuracy: 0.8114 - gender_out_mae: 0.2533 - age_out_accuracy: 0.0015 - age_out_mae: 0.2230
# Epoch 4: val_loss improved from 0.68867 to 0.64530, saving model to model1-RGB.h5
# 208/208 [==============================] - 18s 88ms/step - loss: 0.6366 - gender_out_loss: 0.4136 - age_out_loss: 0.2230 - gender_out_accuracy: 0.8118 - gender_out_mae: 0.2531 - age_out_accuracy: 0.0015 - age_out_mae: 0.2230 - val_loss: 0.6453 - val_gender_out_loss: 0.4203 - val_age_out_loss: 0.2250 - val_gender_out_accuracy: 0.8004 - val_gender_out_mae: 0.2603 - val_age_out_accuracy: 0.0021 - val_age_out_mae: 0.2250
# Epoch 5/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.5656 - gender_out_loss: 0.3633 - age_out_loss: 0.2023 - gender_out_accuracy: 0.8409 - gender_out_mae: 0.2234 - age_out_accuracy: 0.0018 - age_out_mae: 0.2023
# Epoch 5: val_loss did not improve from 0.64530
# 208/208 [==============================] - 16s 77ms/step - loss: 0.5654 - gender_out_loss: 0.3631 - age_out_loss: 0.2023 - gender_out_accuracy: 0.8409 - gender_out_mae: 0.2233 - age_out_accuracy: 0.0018 - age_out_mae: 0.2023 - val_loss: 0.7010 - val_gender_out_loss: 0.4448 - val_age_out_loss: 0.2562 - val_gender_out_accuracy: 0.8025 - val_gender_out_mae: 0.2549 - val_age_out_accuracy: 2.9918e-04 - val_age_out_mae: 0.2562
# Epoch 6/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.5249 - gender_out_loss: 0.3319 - age_out_loss: 0.1931 - gender_out_accuracy: 0.8596 - gender_out_mae: 0.2035 - age_out_accuracy: 0.0020 - age_out_mae: 0.1931
# Epoch 6: val_loss improved from 0.64530 to 0.53875, saving model to model1-RGB.h5
# 208/208 [==============================] - 19s 89ms/step - loss: 0.5248 - gender_out_loss: 0.3318 - age_out_loss: 0.1930 - gender_out_accuracy: 0.8597 - gender_out_mae: 0.2035 - age_out_accuracy: 0.0020 - age_out_mae: 0.1930 - val_loss: 0.5388 - val_gender_out_loss: 0.3622 - val_age_out_loss: 0.1766 - val_gender_out_accuracy: 0.8396 - val_gender_out_mae: 0.2416 - val_age_out_accuracy: 0.0033 - val_age_out_mae: 0.1766
# Epoch 7/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.4699 - gender_out_loss: 0.2907 - age_out_loss: 0.1791 - gender_out_accuracy: 0.8779 - gender_out_mae: 0.1784 - age_out_accuracy: 0.0023 - age_out_mae: 0.1791
# Epoch 7: val_loss did not improve from 0.53875
# 208/208 [==============================] - 18s 88ms/step - loss: 0.4704 - gender_out_loss: 0.2912 - age_out_loss: 0.1792 - gender_out_accuracy: 0.8777 - gender_out_mae: 0.1785 - age_out_accuracy: 0.0023 - age_out_mae: 0.1792 - val_loss: 0.7098 - val_gender_out_loss: 0.4733 - val_age_out_loss: 0.2365 - val_gender_out_accuracy: 0.7568 - val_gender_out_mae: 0.3168 - val_age_out_accuracy: 0.0039 - val_age_out_mae: 0.2365
# Epoch 8/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.4453 - gender_out_loss: 0.2684 - age_out_loss: 0.1769 - gender_out_accuracy: 0.8886 - gender_out_mae: 0.1635 - age_out_accuracy: 0.0029 - age_out_mae: 0.1769
# Epoch 8: val_loss did not improve from 0.53875
# 208/208 [==============================] - 16s 77ms/step - loss: 0.4456 - gender_out_loss: 0.2686 - age_out_loss: 0.1770 - gender_out_accuracy: 0.8885 - gender_out_mae: 0.1635 - age_out_accuracy: 0.0029 - age_out_mae: 0.1770 - val_loss: 0.5671 - val_gender_out_loss: 0.4107 - val_age_out_loss: 0.1565 - val_gender_out_accuracy: 0.8049 - val_gender_out_mae: 0.2299 - val_age_out_accuracy: 0.0036 - val_age_out_mae: 0.1565
# Epoch 9/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.4215 - gender_out_loss: 0.2553 - age_out_loss: 0.1661 - gender_out_accuracy: 0.8966 - gender_out_mae: 0.1525 - age_out_accuracy: 0.0021 - age_out_mae: 0.1661
# Epoch 9: val_loss improved from 0.53875 to 0.47156, saving model to model1-RGB.h5
# 208/208 [==============================] - 16s 79ms/step - loss: 0.4215 - gender_out_loss: 0.2554 - age_out_loss: 0.1661 - gender_out_accuracy: 0.8966 - gender_out_mae: 0.1526 - age_out_accuracy: 0.0021 - age_out_mae: 0.1661 - val_loss: 0.4716 - val_gender_out_loss: 0.3148 - val_age_out_loss: 0.1568 - val_gender_out_accuracy: 0.8615 - val_gender_out_mae: 0.1906 - val_age_out_accuracy: 0.0033 - val_age_out_mae: 0.1568
# Epoch 10/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.3841 - gender_out_loss: 0.2256 - age_out_loss: 0.1584 - gender_out_accuracy: 0.9035 - gender_out_mae: 0.1367 - age_out_accuracy: 0.0032 - age_out_mae: 0.1584
# Epoch 10: val_loss improved from 0.47156 to 0.46769, saving model to model1-RGB.h5
# 208/208 [==============================] - 18s 89ms/step - loss: 0.3840 - gender_out_loss: 0.2256 - age_out_loss: 0.1584 - gender_out_accuracy: 0.9036 - gender_out_mae: 0.1367 - age_out_accuracy: 0.0032 - age_out_mae: 0.1584 - val_loss: 0.4677 - val_gender_out_loss: 0.3199 - val_age_out_loss: 0.1477 - val_gender_out_accuracy: 0.8721 - val_gender_out_mae: 0.1599 - val_age_out_accuracy: 0.0024 - val_age_out_mae: 0.1477
# Epoch 11/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.3678 - gender_out_loss: 0.2161 - age_out_loss: 0.1517 - gender_out_accuracy: 0.9133 - gender_out_mae: 0.1286 - age_out_accuracy: 0.0030 - age_out_mae: 0.1517
# Epoch 11: val_loss improved from 0.46769 to 0.43863, saving model to model1-RGB.h5
# 208/208 [==============================] - 18s 89ms/step - loss: 0.3677 - gender_out_loss: 0.2160 - age_out_loss: 0.1517 - gender_out_accuracy: 0.9134 - gender_out_mae: 0.1286 - age_out_accuracy: 0.0030 - age_out_mae: 0.1517 - val_loss: 0.4386 - val_gender_out_loss: 0.2995 - val_age_out_loss: 0.1391 - val_gender_out_accuracy: 0.8827 - val_gender_out_mae: 0.1480 - val_age_out_accuracy: 0.0031 - val_age_out_mae: 0.1391
# Epoch 12/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.3361 - gender_out_loss: 0.1917 - age_out_loss: 0.1443 - gender_out_accuracy: 0.9233 - gender_out_mae: 0.1125 - age_out_accuracy: 0.0027 - age_out_mae: 0.1443
# Epoch 12: val_loss improved from 0.43863 to 0.43475, saving model to model1-RGB.h5
# 208/208 [==============================] - 16s 79ms/step - loss: 0.3360 - gender_out_loss: 0.1916 - age_out_loss: 0.1445 - gender_out_accuracy: 0.9235 - gender_out_mae: 0.1125 - age_out_accuracy: 0.0027 - age_out_mae: 0.1445 - val_loss: 0.4347 - val_gender_out_loss: 0.2885 - val_age_out_loss: 0.1462 - val_gender_out_accuracy: 0.8808 - val_gender_out_mae: 0.1579 - val_age_out_accuracy: 0.0037 - val_age_out_mae: 0.1462
# Epoch 13/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.3136 - gender_out_loss: 0.1766 - age_out_loss: 0.1370 - gender_out_accuracy: 0.9290 - gender_out_mae: 0.1032 - age_out_accuracy: 0.0027 - age_out_mae: 0.1370
# Epoch 13: val_loss improved from 0.43475 to 0.43334, saving model to model1-RGB.h5
# 208/208 [==============================] - 17s 80ms/step - loss: 0.3136 - gender_out_loss: 0.1765 - age_out_loss: 0.1371 - gender_out_accuracy: 0.9290 - gender_out_mae: 0.1032 - age_out_accuracy: 0.0027 - age_out_mae: 0.1371 - val_loss: 0.4333 - val_gender_out_loss: 0.3019 - val_age_out_loss: 0.1315 - val_gender_out_accuracy: 0.8874 - val_gender_out_mae: 0.1395 - val_age_out_accuracy: 0.0030 - val_age_out_mae: 0.1315
# Epoch 14/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.2844 - gender_out_loss: 0.1514 - age_out_loss: 0.1330 - gender_out_accuracy: 0.9414 - gender_out_mae: 0.0879 - age_out_accuracy: 0.0035 - age_out_mae: 0.1330
# Epoch 14: val_loss did not improve from 0.43334
# 208/208 [==============================] - 16s 78ms/step - loss: 0.2844 - gender_out_loss: 0.1514 - age_out_loss: 0.1329 - gender_out_accuracy: 0.9412 - gender_out_mae: 0.0879 - age_out_accuracy: 0.0035 - age_out_mae: 0.1329 - val_loss: 0.5245 - val_gender_out_loss: 0.3925 - val_age_out_loss: 0.1320 - val_gender_out_accuracy: 0.8652 - val_gender_out_mae: 0.1570 - val_age_out_accuracy: 0.0031 - val_age_out_mae: 0.1320
# Epoch 15/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.2749 - gender_out_loss: 0.1457 - age_out_loss: 0.1292 - gender_out_accuracy: 0.9417 - gender_out_mae: 0.0843 - age_out_accuracy: 0.0032 - age_out_mae: 0.1292
# Epoch 15: val_loss did not improve from 0.43334
# 208/208 [==============================] - 18s 88ms/step - loss: 0.2750 - gender_out_loss: 0.1458 - age_out_loss: 0.1292 - gender_out_accuracy: 0.9417 - gender_out_mae: 0.0843 - age_out_accuracy: 0.0032 - age_out_mae: 0.1292 - val_loss: 0.4469 - val_gender_out_loss: 0.3100 - val_age_out_loss: 0.1368 - val_gender_out_accuracy: 0.8714 - val_gender_out_mae: 0.1652 - val_age_out_accuracy: 0.0037 - val_age_out_mae: 0.1368
# Epoch 16/20
# 207/208 [============================>.] - ETA: 0s - loss: 0.2458 - gender_out_loss: 0.1245 - age_out_loss: 0.1213 - gender_out_accuracy: 0.9515 - gender_out_mae: 0.0726 - age_out_accuracy: 0.0035 - age_out_mae: 0.1213
# Epoch 16: val_loss did not improve from 0.43334
# 208/208 [==============================] - 16s 78ms/step - loss: 0.2457 - gender_out_loss: 0.1243 - age_out_loss: 0.1214 - gender_out_accuracy: 0.9516 - gender_out_mae: 0.0725 - age_out_accuracy: 0.0036 - age_out_mae: 0.1214 - val_loss: 0.4442 - val_gender_out_loss: 0.3239 - val_age_out_loss: 0.1203 - val_gender_out_accuracy: 0.8918 - val_gender_out_mae: 0.1260 - val_age_out_accuracy: 0.0036 - val_age_out_mae: 0.1203

# %%
# Obtener las métricas del historial
train_loss = history.history['loss']
train_gender_loss = history.history['gender_out_loss']
train_age_loss = history.history['age_out_loss']
train_gender_accuracy = history.history['gender_out_accuracy']
train_age_mae = history.history['age_out_mae']

val_loss = history.history['val_loss']
val_gender_loss = history.history['val_gender_out_loss']
val_age_loss = history.history['val_age_out_loss']
val_gender_accuracy = history.history['val_gender_out_accuracy']
val_age_mae = history.history['val_age_out_mae']

titulo = 'model2-10epoch'

# Graficar las curvas de pérdida
plt.figure(figsize=(6, 4))
plt.title(titulo)

plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Graficar las curvas de precisión
plt.figure(figsize=(6, 4))
plt.title(titulo)
plt.plot(train_gender_accuracy, label='Train Gender Accuracy')
plt.plot(val_gender_accuracy, label='Val Gender Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Graficar las curvas de error:
plt.figure(figsize=(6, 4))
plt.title(titulo)
plt.plot(train_age_mae, label='Train Age mae')
plt.plot(val_age_mae, label='Val Age mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()

plt.tight_layout()
plt.show()

# %%
pred = model.predict(X_val)

y_age_pred = np.round(80*pred[1],2)
y_gender_pred = np.round(pred[0],2)
# Out:
# 209/209 [==============================] - 3s 14ms/step

# %%
model.evaluate(X_val, [y_gender_val, y_age_val])
# Out:
# 209/209 [==============================] - 4s 16ms/step - loss: 0.4333 - gender_out_loss: 0.3019 - age_out_loss: 0.1315 - gender_out_accuracy: 0.8874 - gender_out_mae: 0.1395 - age_out_accuracy: 0.0030 - age_out_mae: 0.1315
# [0.4333370327949524,
#  0.3018689453601837,
#  0.13146816194057465,
#  0.8873597383499146,
#  0.13952060043811798,
#  0.002991772722452879,
#  0.13146816194057465]

# %%
# Verificamos que todo esté correcto:
plt.figure(figsize=(10, 6))

paso = np.random.randint(0,6685-16)
paso = 0
for i in range(15):
    plt.subplot(3, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_val[i+paso])
    plt.xlabel(f'Age: P: {int(y_age_pred[i+paso])}, R: {y_age_raw_val[i+paso]}')
    plt.ylabel(f'Gender: P: {int(y_gender_pred[i+paso])}, R: {y_gender_val[i+paso]}')
plt.show()

# %%
error_edad=np.zeros(len(range(2,81)))
count_edad = np.zeros(len(range(2,81)))
x_error_edad = np.array(range(2,81))

for y_edad, predicho in zip(y_age_raw_val, y_age_pred):
    for i_edad, edad in enumerate(x_error_edad):
        if edad == y_edad:
            
            count_edad[i_edad]+=1 
            error_edad[i_edad] += abs(y_edad-float(predicho))
            

error_edad = error_edad / count_edad

# %%
plt.bar(x_error_edad, error_edad)
plt.title('Error por edades')
plt.ylabel('Error absoluto medio')
plt.xlabel('Edad')
plt.show()

# %% [markdown]
# Como podemos observar, ha mejorado el desempeño con respecto a la versión que entrenamos en local al entrenar durante más epochs

# %% [markdown]
# ![image.png](data:image/png;base64,...)
